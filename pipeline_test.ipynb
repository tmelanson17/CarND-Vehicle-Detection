# %%
from pipeline_ssd import *
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

img = imread('./corner-case.png')
model_params = init_model()
# Out:
# /Users/thomasmelanson/miniconda3/envs/deeplearning-inference/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /Users/thomasmelanson/miniconda3/envs/deeplearning-inference/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)
# /Users/thomasmelanson/miniconda3/envs/deeplearning-inference/lib/python3.5/site-packages/ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """
# ssd_keras/ssd.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), name="conv1_1", padding="same", activation="relu")`
#   name='conv1_1')(net['input'])
# ssd_keras/ssd.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), name="conv1_2", padding="same", activation="relu")`
#   name='conv1_2')(net['conv1_1'])
# ssd_keras/ssd.py:46: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((2, 2), name="pool1", padding="same", strides=(2, 2))`
#   name='pool1')(net['conv1_2'])
# ssd_keras/ssd.py:51: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), name="conv2_1", padding="same", activation="relu")`
#   name='conv2_1')(net['pool1'])
# ssd_keras/ssd.py:55: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), name="conv2_2", padding="same", activation="relu")`
#   name='conv2_2')(net['conv2_1'])
# ssd_keras/ssd.py:57: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((2, 2), name="pool2", padding="same", strides=(2, 2))`
#   name='pool2')(net['conv2_2'])
# ssd_keras/ssd.py:62: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), name="conv3_1", padding="same", activation="relu")`
#   name='conv3_1')(net['pool2'])
# ssd_keras/ssd.py:66: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), name="conv3_2", padding="same", activation="relu")`
#   name='conv3_2')(net['conv3_1'])
# ssd_keras/ssd.py:70: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), name="conv3_3", padding="same", activation="relu")`
#   name='conv3_3')(net['conv3_2'])
# ssd_keras/ssd.py:72: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((2, 2), name="pool3", padding="same", strides=(2, 2))`
#   name='pool3')(net['conv3_3'])
# ssd_keras/ssd.py:77: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), name="conv4_1", padding="same", activation="relu")`
#   name='conv4_1')(net['pool3'])
# ssd_keras/ssd.py:81: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), name="conv4_2", padding="same", activation="relu")`
#   name='conv4_2')(net['conv4_1'])
# ssd_keras/ssd.py:85: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), name="conv4_3", padding="same", activation="relu")`
#   name='conv4_3')(net['conv4_2'])
# ssd_keras/ssd.py:87: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((2, 2), name="pool4", padding="same", strides=(2, 2))`
#   name='pool4')(net['conv4_3'])
# ssd_keras/ssd.py:92: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), name="conv5_1", padding="same", activation="relu")`
#   name='conv5_1')(net['pool4'])
# ssd_keras/ssd.py:96: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), name="conv5_2", padding="same", activation="relu")`
#   name='conv5_2')(net['conv5_1'])
# ssd_keras/ssd.py:100: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), name="conv5_3", padding="same", activation="relu")`
#   name='conv5_3')(net['conv5_2'])
# ssd_keras/ssd.py:102: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((3, 3), name="pool5", padding="same", strides=(1, 1))`
#   name='pool5')(net['conv5_3'])
# /Users/thomasmelanson/miniconda3/envs/deeplearning-inference/lib/python3.5/site-packages/keras/legacy/layers.py:762: UserWarning: The `AtrousConvolution2D` layer  has been deprecated. Use instead the `Conv2D` layer with the `dilation_rate` argument.
#   warnings.warn('The `AtrousConvolution2D` layer '
# /Users/thomasmelanson/miniconda3/envs/deeplearning-inference/lib/python3.5/site-packages/keras/legacy/layers.py:766: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (3, 3), name="fc6", dilation_rate=(6, 6), padding="same", activation="relu")`
#   return Conv2D(*args, **kwargs)
# ssd_keras/ssd.py:110: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), name="fc7", padding="same", activation="relu")`
#   border_mode='same', name='fc7')(net['fc6'])
# ssd_keras/ssd.py:115: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), name="conv6_1", padding="same", activation="relu")`
#   name='conv6_1')(net['fc7'])
# ssd_keras/ssd.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), name="conv6_2", padding="same", strides=(2, 2), activation="relu")`
#   name='conv6_2')(net['conv6_1'])
# ssd_keras/ssd.py:122: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv7_1", padding="same", activation="relu")`
#   name='conv7_1')(net['conv6_2'])
# ssd_keras/ssd.py:126: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), name="conv7_2", padding="valid", strides=(2, 2), activation="relu")`
#   name='conv7_2')(net['conv7_2'])
# ssd_keras/ssd.py:130: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv8_1", padding="same", activation="relu")`
#   name='conv8_1')(net['conv7_2'])
# ssd_keras/ssd.py:133: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), name="conv8_2", padding="same", strides=(2, 2), activation="relu")`
#   name='conv8_2')(net['conv8_1'])
# ssd_keras/ssd.py:140: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(12, (3, 3), name="conv4_3_norm_mbox_loc", padding="same")`
#   name='conv4_3_norm_mbox_loc')(net['conv4_3_norm'])
# ssd_keras/ssd.py:148: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(63, (3, 3), name="conv4_3_norm_mbox_conf", padding="same")`
#   name=name)(net['conv4_3_norm'])
# ssd_keras/ssd.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (3, 3), name="fc7_mbox_loc", padding="same")`
#   name='fc7_mbox_loc')(net['fc7'])
# ssd_keras/ssd.py:168: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(126, (3, 3), name="fc7_mbox_conf", padding="same")`
#   name=name)(net['fc7'])
# ssd_keras/ssd.py:178: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (3, 3), name="conv6_2_mbox_loc", padding="same")`
#   name='conv6_2_mbox_loc')(net['conv6_2'])
# ssd_keras/ssd.py:186: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(126, (3, 3), name="conv6_2_mbox_conf", padding="same")`
#   name=name)(net['conv6_2'])
# ssd_keras/ssd.py:197: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (3, 3), name="conv7_2_mbox_loc", padding="same")`
#   name='conv7_2_mbox_loc')(net['conv7_2'])
# ssd_keras/ssd.py:205: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(126, (3, 3), name="conv7_2_mbox_conf", padding="same")`
#   name=name)(net['conv7_2'])
# ssd_keras/ssd.py:216: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (3, 3), name="conv8_2_mbox_loc", padding="same")`
#   name='conv8_2_mbox_loc')(net['conv8_2'])
# ssd_keras/ssd.py:224: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(126, (3, 3), name="conv8_2_mbox_conf", padding="same")`
#   name=name)(net['conv8_2'])
# ssd_keras/ssd.py:258: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   mode='concat', concat_axis=1, name='mbox_loc')
# /Users/thomasmelanson/miniconda3/envs/deeplearning-inference/lib/python3.5/site-packages/keras/legacy/layers.py:465: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# ssd_keras/ssd.py:265: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   mode='concat', concat_axis=1, name='mbox_conf')
# ssd_keras/ssd.py:273: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name='mbox_priorbox')
# ssd_keras/ssd.py:288: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name='predictions')

# %%
img = img[:,:,:3]
draw = pipeline(img, model_params)
plt.figure()
plt.imshow(draw)
